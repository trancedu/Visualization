# %% [markdown]
# # <center>Class 2</center>
#
# ## Objectives
# In this class we will learn:
# <ul>
#     <li>How to initialize dash</li>
#     <li>Defining HTML components within an app</li>
#     <li>Looking at the different native dash components</li>
#     <li>Show a graph in a demo page</li>
# </ul>

# %% [markdown]
# ### Creating a website with python

# %% [markdown]
# *These are the main imports needed in any dash web app*

# %%
import dash
from dash import html, dcc

# This is only needed to that we can run dash in a notebook
from jupyter_dash import JupyterDash

# %%
# First thing we need to do is create the contents and initialize the app
app = JupyterDash(__name__)     # in a python py file this should be app = dash.Dash()

app.layout = html.Div(
    [
        html.H1("This is a Dash Web App", style = {'border-style': 'solid'}),
        html.Div(
            [
                html.Div("I am an html div element. In dash I am an html.Div element"),
                html.Div("I am a second Div element. I show up in the next line"),
                html.Div("I am a third Div element. We are all the children of the main Div above. We are a list of elements"),            
                dcc.Link("Here's a link to the documentation for a Div", href = "https://dash.plotly.com/dash-html-components/div"),
                html.Br(),
                html.Br(),
                html.Div("And after a break, I am a centered Div", style = {'text-align': 'center'})
            ], style = {
                # Let's play around with a few styles
                #'background': '#e7e7e7', 
                'height': '20em', 
                'margin': '4em 2em 3em 4em',
                #'display': 'flex', 'flex-direction': 'row'
            }
        )
    ], style = {'border-style': 'solid'}
)

print(html.H1("This is a Dash Web App", style = {'border-style': 'solid'}))

# This is always the last line where the app is actually instanciated
app.run_server(
    mode = 'inline'
   ,port = 8058
)
# Out:
# H1(children='This is a Dash Web App', style={'border-style': 'solid'})
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8058/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Adding some more html tags contents

# %%
# Extra variables
border = {'border-style': 'solid', 'border-width': 'thin'}
image_url = "https://steinhardt.nyu.edu/sites/default/files/styles/media_image_large/public/2019-08/nyu-logo-new.png?h=9396f34a&itok=hA0gNV3D"
from datetime import date

def text():
    return("H1 Tag - I am the first of the H's")

# First thing we need to do is create the contents and initialize the app
app = JupyterDash(__name__)     # in a python py file this should be app = dash.Dash()

app.layout = html.Div(
    [
        html.Header('These are some common HTML tags', style = {'font-size':'2em', 'color': 'blue', 'font-weight': 'bold'}),
        html.H1(text(), style = border),
        html.H3("H3 Tag", style = border),
        html.H6("H6 Tag - I am the last of the H's", style = border),
        html.H6("I'm a huge H6 thanks to my style", style = {**border, **{'font-size':'2em'}}),
        html.P(["I am a paragraph. &nbsp;         "]*20, style = border),
        html.Div(["I am a div.          "]*20, style = border),
        html.Label(["I am a label. "]*20, style = {**border, **{'background': '#e7e7e7' }}),
        html.Br(),html.Br(),
        html.Button('I am a button'),
        html.Br(),
        html.Label('I am the label for the next image: (notice I cannot add space at the end)   '), 
        html.Br(),
        html.Img(src=image_url, style = {'height': '100px', 'width': '200px'}),
        html.Ul(
            [
                html.Li('I am a list element'),
                html.Li('I am a list element'),
            ]
        ),
        html.Textarea(placeholder  = 'I am a text area with a placeholder'),
        
        html.Hr(),
        html.Header('And these are some Dash Core Components', style = {'font-size':'2em', 'color': 'blue', 'font-weight': 'bold'}),
        html.Label("DCC's are wrappers for regular html"),
        dcc.Dropdown(
            options=[
                {'label': 'NYU', 'value': 0}
            ],
            placeholder = 'Select something...'
        ),
        dcc.Input(
            type='text',
            placeholder='I am a text input'
        ),
        dcc.Input(
            type='number',
            placeholder='I am also text input but I only take numbers'
        ),
        dcc.Input(
            type='range',
            placeholder='Can I?'
        ),
        html.Br(),
        dcc.DatePickerRange(
            min_date_allowed=date(1995, 8, 5),
            max_date_allowed=date(2017, 9, 19),
            initial_visible_month=date(2021, 11, 2),
            end_date=date(2021, 12, 25)
        ),
        html.Br(),
        dcc.RadioItems(
            options=[
                {'label': 'NYU', 'value': 0},
            ],
        )
        
    ], style = {'border-style': 'solid', 'padding': '5em'}
)

# This is always the last line where the app is actually instanciated
app.run_server(
    mode = 'inline'
)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Let's get deeper into the DCC components
# Since we are in a python environment we can populate components dynamically. For example, we can download a list of cities from the web.

# %%
import pandas as pd
cities = pd.read_csv('data/world-cities.csv')
cities = cities.loc[cities['country']=='United States']

# Recall that in dash, all children elements are lists. So we can create the options as a list of dictionaries:
city_options = [{'label': city, 'value': num} for num, city in enumerate(cities['name'])]
for x in city_options:
    print(x)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# c:\Users\29468\anaconda3\lib\site-packages\flask\app.py in full_dispatch_request(self=<Flask '__main__'>)
#    1948             rv = self.preprocess_request()
#    1949             if rv is None:
# -> 1950                 rv = self.dispatch_request()
#         rv = None
#         self.dispatch_request = <bound method Flask.dispatch_request of <Flask '__main__'>>
#    1951         except Exception as e:
#    1952             rv = self.handle_user_exception(e)
#
# c:\Users\29468\anaconda3\lib\site-packages\flask\app.py in dispatch_request(self=<Flask '__main__'>)
#    1934             return self.make_default_options_response()
#    1935         # otherwise dispatch to the handler for that endpoint
# -> 1936         return self.view_functions[rule.endpoint](**req.view_args)
#         self.view_functions = {'static': <bound method _PackageBoundObject.send_static_file of <Flask '__main__'>>, '_dash_assets.static': <bound method _PackageBoundObject.send_static_file of <flask.blueprints.Blueprint object at 0x000001C5844DA8E0>>, '/_dash-component-suites/<string:package_name>/<path:fingerprinted_path>': <bound method Dash.serve_component_suites of <jupyter_dash.jupyter_app.JupyterDash object at 0x000001C5843BC640>>, '/_dash-layout': <bound method Dash.serve_layout of <jupyter_dash.jupyter_app.JupyterDash object at 0x000001C5843BC640>>, '/_dash-dependencies': <bound method Dash.dependencies of <jupyter_dash.jupyter_app.JupyterDash object at 0x000001C5843BC640>>, '/_dash-update-component': <bound method Dash.dispatch of <jupyter_dash.jupyter_app.JupyterDash object at 0x000001C5843BC640>>, '/_reload-hash': <bound method Dash.serve_reload_hash of <jupyter_dash.jupyter_app.JupyterDash object at 0x000001C5843BC640>>, '/_favicon.ico': <function Dash._serve_default_favicon at 0x000001C583E664C0>, '/': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x000001C5843BC640>>, '/<path:path>': <bound method Dash.index of <jupyter_dash.jupyter_app.JupyterDash object at 0x000001C5843BC640>>, 'alive': <function JupyterDash.__init__.<locals>.alive at 0x000001C58285EF70>}
#         rule.endpoint = '/_dash-layout'
#         req.view_args = {}
#    1937
#    1938     def full_dispatch_request(self):
#
# c:\Users\29468\anaconda3\lib\site-packages\dash\dash.py in serve_layout(
#     self=<jupyter_dash.jupyter_app.JupyterDash object>
# )
#     602         # TODO - Set browser cache limit - pass hash into frontend
#     603         return flask.Response(
# --> 604             to_json(layout),
#         global to_json = <function to_json at 0x000001C582CD3040>
#         layout = Div(children=[Header(children='These are some common HTML tags', style={'font-size': '2em', 'color': 'blue', 'font-weight': 'bold'}), H1(children="H1 Tag - I am the first of the H's", style={'border-style': 'solid', 'border-width': 'thin'}), H3(children='H3 Tag', style={'border-style': 'solid', 'border-width': 'thin'}), H6(children="H6 Tag - I am the last of the H's", style={'border-style': 'solid', 'border-width': 'thin'}), H6(children="I'm a huge H6 thanks to my style", style={'border-style': 'solid', 'border-width': 'thin', 'font-size': '2em'}), P(children=['I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         '], style={'border-style': 'solid', 'border-width': 'thin'}), Div(children=['I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          '], style={'border-style': 'solid', 'border-width': 'thin'}), Label(children=['I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. '], style={'border-style': 'solid', 'border-width': 'thin', 'background': '#e7e7e7'}), Br(None), Br(None), Button('I am a button'), Br(None), Label('I am the label for the next image: (notice I cannot add space at the end)   '), Br(None), Img(src='https://steinhardt.nyu.edu/sites/default/files/styles/media_image_large/public/2019-08/nyu-logo-new.png?h=9396f34a&itok=hA0gNV3D', style={'height': '100px', 'width': '200px'}), Ul([Li('I am a list element'), Li('I am a list element')]), Textarea(placeholder='I am a text area with a placeholder'), Hr(None), Header(children='And these are some Dash Core Components', style={'font-size': '2em', 'color': 'blue', 'font-weight': 'bold'}), Label("DCC's are wrappers for regular html"), Dropdown(options=[{'label': 'NYU', 'value': 0}], placeholder='Select something...'), Input(type='text', placeholder='I am a text input'), Input(type='number', placeholder='I am also text input but I only take numbers'), Input(type='range', placeholder='Can I?'), Br(None), DatePickerRange(end_date=datetime.date(2021, 12, 25), min_date_allowed=datetime.date(1995, 8, 5), max_date_allowed=datetime.date(2017, 9, 19), initial_visible_month=datetime.date(2021, 11, 2)), Br(None), RadioItems(options=[{'label': 'NYU', 'value': 0}])], style={'border-style': 'solid', 'padding': '5em'})
#     605             mimetype="application/json",
#     606         )
#
# c:\Users\29468\anaconda3\lib\site-packages\dash\_utils.py in to_json(
#     value=Div(children=[Header(children='These are some co...tyle={'border-style': 'solid', 'padding': '5em'})
# )
#      20     from plotly.io.json import to_json_plotly
#      21
# ---> 22     return to_json_plotly(value)
#         to_json_plotly = <function to_json_plotly at 0x000001C5844C50D0>
#         value = Div(children=[Header(children='These are some common HTML tags', style={'font-size': '2em', 'color': 'blue', 'font-weight': 'bold'}), H1(children="H1 Tag - I am the first of the H's", style={'border-style': 'solid', 'border-width': 'thin'}), H3(children='H3 Tag', style={'border-style': 'solid', 'border-width': 'thin'}), H6(children="H6 Tag - I am the last of the H's", style={'border-style': 'solid', 'border-width': 'thin'}), H6(children="I'm a huge H6 thanks to my style", style={'border-style': 'solid', 'border-width': 'thin', 'font-size': '2em'}), P(children=['I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         '], style={'border-style': 'solid', 'border-width': 'thin'}), Div(children=['I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          '], style={'border-style': 'solid', 'border-width': 'thin'}), Label(children=['I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. '], style={'border-style': 'solid', 'border-width': 'thin', 'background': '#e7e7e7'}), Br(None), Br(None), Button('I am a button'), Br(None), Label('I am the label for the next image: (notice I cannot add space at the end)   '), Br(None), Img(src='https://steinhardt.nyu.edu/sites/default/files/styles/media_image_large/public/2019-08/nyu-logo-new.png?h=9396f34a&itok=hA0gNV3D', style={'height': '100px', 'width': '200px'}), Ul([Li('I am a list element'), Li('I am a list element')]), Textarea(placeholder='I am a text area with a placeholder'), Hr(None), Header(children='And these are some Dash Core Components', style={'font-size': '2em', 'color': 'blue', 'font-weight': 'bold'}), Label("DCC's are wrappers for regular html"), Dropdown(options=[{'label': 'NYU', 'value': 0}], placeholder='Select something...'), Input(type='text', placeholder='I am a text input'), Input(type='number', placeholder='I am also text input but I only take numbers'), Input(type='range', placeholder='Can I?'), Br(None), DatePickerRange(end_date=datetime.date(2021, 12, 25), min_date_allowed=datetime.date(1995, 8, 5), max_date_allowed=datetime.date(2017, 9, 19), initial_visible_month=datetime.date(2021, 11, 2)), Br(None), RadioItems(options=[{'label': 'NYU', 'value': 0}])], style={'border-style': 'solid', 'padding': '5em'})
#      23
#      24
#
# c:\Users\29468\anaconda3\lib\site-packages\plotly\io\_json.py in to_json_plotly(
#     plotly_object=Div(children=[Header(children='These are some co...tyle={'border-style': 'solid', 'padding': '5em'}),
#     pretty=False,
#     engine='json'
# )
#     121         from _plotly_utils.utils import PlotlyJSONEncoder
#     122
# --> 123         return json.dumps(plotly_object, cls=PlotlyJSONEncoder, **opts)
#         global json.dumps = <function dumps at 0x000001C5FE476550>
#         plotly_object = Div(children=[Header(children='These are some common HTML tags', style={'font-size': '2em', 'color': 'blue', 'font-weight': 'bold'}), H1(children="H1 Tag - I am the first of the H's", style={'border-style': 'solid', 'border-width': 'thin'}), H3(children='H3 Tag', style={'border-style': 'solid', 'border-width': 'thin'}), H6(children="H6 Tag - I am the last of the H's", style={'border-style': 'solid', 'border-width': 'thin'}), H6(children="I'm a huge H6 thanks to my style", style={'border-style': 'solid', 'border-width': 'thin', 'font-size': '2em'}), P(children=['I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         '], style={'border-style': 'solid', 'border-width': 'thin'}), Div(children=['I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          '], style={'border-style': 'solid', 'border-width': 'thin'}), Label(children=['I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. '], style={'border-style': 'solid', 'border-width': 'thin', 'background': '#e7e7e7'}), Br(None), Br(None), Button('I am a button'), Br(None), Label('I am the label for the next image: (notice I cannot add space at the end)   '), Br(None), Img(src='https://steinhardt.nyu.edu/sites/default/files/styles/media_image_large/public/2019-08/nyu-logo-new.png?h=9396f34a&itok=hA0gNV3D', style={'height': '100px', 'width': '200px'}), Ul([Li('I am a list element'), Li('I am a list element')]), Textarea(placeholder='I am a text area with a placeholder'), Hr(None), Header(children='And these are some Dash Core Components', style={'font-size': '2em', 'color': 'blue', 'font-weight': 'bold'}), Label("DCC's are wrappers for regular html"), Dropdown(options=[{'label': 'NYU', 'value': 0}], placeholder='Select something...'), Input(type='text', placeholder='I am a text input'), Input(type='number', placeholder='I am also text input but I only take numbers'), Input(type='range', placeholder='Can I?'), Br(None), DatePickerRange(end_date=datetime.date(2021, 12, 25), min_date_allowed=datetime.date(1995, 8, 5), max_date_allowed=datetime.date(2017, 9, 19), initial_visible_month=datetime.date(2021, 11, 2)), Br(None), RadioItems(options=[{'label': 'NYU', 'value': 0}])], style={'border-style': 'solid', 'padding': '5em'})
#         global cls = undefined
#         PlotlyJSONEncoder = <class '_plotly_utils.utils.PlotlyJSONEncoder'>
#         opts = {'separators': (',', ':')}
#     124     elif engine == "orjson":
#     125         JsonConfig.validate_orjson()
#
# c:\Users\29468\anaconda3\lib\json\__init__.py in dumps(
#     obj=Div(children=[Header(children='These are some co...tyle={'border-style': 'solid', 'padding': '5em'}),
#     skipkeys=False,
#     ensure_ascii=True,
#     check_circular=True,
#     allow_nan=True,
#     cls=<class '_plotly_utils.utils.PlotlyJSONEncoder'>,
#     indent=None,
#     separators=(',', ':'),
#     default=None,
#     sort_keys=False,
#     **kw={}
# )
#     232     if cls is None:
#     233         cls = JSONEncoder
# --> 234     return cls(
#         cls = <class '_plotly_utils.utils.PlotlyJSONEncoder'>
#         skipkeys = False
#         ensure_ascii = True
#         check_circular = True
#         allow_nan = True
#         indent = None
#         separators = (',', ':')
#         default = None
#         sort_keys = False
#         kw.encode = undefined
#         obj = Div(children=[Header(children='These are some common HTML tags', style={'font-size': '2em', 'color': 'blue', 'font-weight': 'bold'}), H1(children="H1 Tag - I am the first of the H's", style={'border-style': 'solid', 'border-width': 'thin'}), H3(children='H3 Tag', style={'border-style': 'solid', 'border-width': 'thin'}), H6(children="H6 Tag - I am the last of the H's", style={'border-style': 'solid', 'border-width': 'thin'}), H6(children="I'm a huge H6 thanks to my style", style={'border-style': 'solid', 'border-width': 'thin', 'font-size': '2em'}), P(children=['I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         '], style={'border-style': 'solid', 'border-width': 'thin'}), Div(children=['I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          '], style={'border-style': 'solid', 'border-width': 'thin'}), Label(children=['I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. '], style={'border-style': 'solid', 'border-width': 'thin', 'background': '#e7e7e7'}), Br(None), Br(None), Button('I am a button'), Br(None), Label('I am the label for the next image: (notice I cannot add space at the end)   '), Br(None), Img(src='https://steinhardt.nyu.edu/sites/default/files/styles/media_image_large/public/2019-08/nyu-logo-new.png?h=9396f34a&itok=hA0gNV3D', style={'height': '100px', 'width': '200px'}), Ul([Li('I am a list element'), Li('I am a list element')]), Textarea(placeholder='I am a text area with a placeholder'), Hr(None), Header(children='And these are some Dash Core Components', style={'font-size': '2em', 'color': 'blue', 'font-weight': 'bold'}), Label("DCC's are wrappers for regular html"), Dropdown(options=[{'label': 'NYU', 'value': 0}], placeholder='Select something...'), Input(type='text', placeholder='I am a text input'), Input(type='number', placeholder='I am also text input but I only take numbers'), Input(type='range', placeholder='Can I?'), Br(None), DatePickerRange(end_date=datetime.date(2021, 12, 25), min_date_allowed=datetime.date(1995, 8, 5), max_date_allowed=datetime.date(2017, 9, 19), initial_visible_month=datetime.date(2021, 11, 2)), Br(None), RadioItems(options=[{'label': 'NYU', 'value': 0}])], style={'border-style': 'solid', 'padding': '5em'})
#     235         skipkeys=skipkeys, ensure_ascii=ensure_ascii,
#     236         check_circular=check_circular, allow_nan=allow_nan, indent=indent,
#
# c:\Users\29468\anaconda3\lib\site-packages\_plotly_utils\utils.py in encode(
#     self=<_plotly_utils.utils.PlotlyJSONEncoder object>,
#     o=Div(children=[Header(children='These are some co...tyle={'border-style': 'solid', 'padding': '5em'})
# )
#      57         """
#      58         # this will raise errors in a normal-expected way
# ---> 59         encoded_o = super(PlotlyJSONEncoder, self).encode(o)
#         encoded_o = undefined
#         global super = undefined
#         global PlotlyJSONEncoder = <class '_plotly_utils.utils.PlotlyJSONEncoder'>
#         self.encode = <bound method PlotlyJSONEncoder.encode of <_plotly_utils.utils.PlotlyJSONEncoder object at 0x000001C58477D3A0>>
#         o = Div(children=[Header(children='These are some common HTML tags', style={'font-size': '2em', 'color': 'blue', 'font-weight': 'bold'}), H1(children="H1 Tag - I am the first of the H's", style={'border-style': 'solid', 'border-width': 'thin'}), H3(children='H3 Tag', style={'border-style': 'solid', 'border-width': 'thin'}), H6(children="H6 Tag - I am the last of the H's", style={'border-style': 'solid', 'border-width': 'thin'}), H6(children="I'm a huge H6 thanks to my style", style={'border-style': 'solid', 'border-width': 'thin', 'font-size': '2em'}), P(children=['I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         '], style={'border-style': 'solid', 'border-width': 'thin'}), Div(children=['I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          '], style={'border-style': 'solid', 'border-width': 'thin'}), Label(children=['I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. '], style={'border-style': 'solid', 'border-width': 'thin', 'background': '#e7e7e7'}), Br(None), Br(None), Button('I am a button'), Br(None), Label('I am the label for the next image: (notice I cannot add space at the end)   '), Br(None), Img(src='https://steinhardt.nyu.edu/sites/default/files/styles/media_image_large/public/2019-08/nyu-logo-new.png?h=9396f34a&itok=hA0gNV3D', style={'height': '100px', 'width': '200px'}), Ul([Li('I am a list element'), Li('I am a list element')]), Textarea(placeholder='I am a text area with a placeholder'), Hr(None), Header(children='And these are some Dash Core Components', style={'font-size': '2em', 'color': 'blue', 'font-weight': 'bold'}), Label("DCC's are wrappers for regular html"), Dropdown(options=[{'label': 'NYU', 'value': 0}], placeholder='Select something...'), Input(type='text', placeholder='I am a text input'), Input(type='number', placeholder='I am also text input but I only take numbers'), Input(type='range', placeholder='Can I?'), Br(None), DatePickerRange(end_date=datetime.date(2021, 12, 25), min_date_allowed=datetime.date(1995, 8, 5), max_date_allowed=datetime.date(2017, 9, 19), initial_visible_month=datetime.date(2021, 11, 2)), Br(None), RadioItems(options=[{'label': 'NYU', 'value': 0}])], style={'border-style': 'solid', 'padding': '5em'})
#      60         # Brute force guessing whether NaN or Infinity values are in the string
#      61         # We catch false positive cases (e.g. strings such as titles, labels etc.)
#
# c:\Users\29468\anaconda3\lib\json\encoder.py in encode(
#     self=<_plotly_utils.utils.PlotlyJSONEncoder object>,
#     o=Div(children=[Header(children='These are some co...tyle={'border-style': 'solid', 'padding': '5em'})
# )
#     197         # exceptions aren't as detailed.  The list call should be roughly
#     198         # equivalent to the PySequence_Fast that ''.join() would do.
# --> 199         chunks = self.iterencode(o, _one_shot=True)
#         chunks = undefined
#         self.iterencode = <bound method JSONEncoder.iterencode of <_plotly_utils.utils.PlotlyJSONEncoder object at 0x000001C58477D3A0>>
#         o = Div(children=[Header(children='These are some common HTML tags', style={'font-size': '2em', 'color': 'blue', 'font-weight': 'bold'}), H1(children="H1 Tag - I am the first of the H's", style={'border-style': 'solid', 'border-width': 'thin'}), H3(children='H3 Tag', style={'border-style': 'solid', 'border-width': 'thin'}), H6(children="H6 Tag - I am the last of the H's", style={'border-style': 'solid', 'border-width': 'thin'}), H6(children="I'm a huge H6 thanks to my style", style={'border-style': 'solid', 'border-width': 'thin', 'font-size': '2em'}), P(children=['I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         '], style={'border-style': 'solid', 'border-width': 'thin'}), Div(children=['I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          '], style={'border-style': 'solid', 'border-width': 'thin'}), Label(children=['I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. '], style={'border-style': 'solid', 'border-width': 'thin', 'background': '#e7e7e7'}), Br(None), Br(None), Button('I am a button'), Br(None), Label('I am the label for the next image: (notice I cannot add space at the end)   '), Br(None), Img(src='https://steinhardt.nyu.edu/sites/default/files/styles/media_image_large/public/2019-08/nyu-logo-new.png?h=9396f34a&itok=hA0gNV3D', style={'height': '100px', 'width': '200px'}), Ul([Li('I am a list element'), Li('I am a list element')]), Textarea(placeholder='I am a text area with a placeholder'), Hr(None), Header(children='And these are some Dash Core Components', style={'font-size': '2em', 'color': 'blue', 'font-weight': 'bold'}), Label("DCC's are wrappers for regular html"), Dropdown(options=[{'label': 'NYU', 'value': 0}], placeholder='Select something...'), Input(type='text', placeholder='I am a text input'), Input(type='number', placeholder='I am also text input but I only take numbers'), Input(type='range', placeholder='Can I?'), Br(None), DatePickerRange(end_date=datetime.date(2021, 12, 25), min_date_allowed=datetime.date(1995, 8, 5), max_date_allowed=datetime.date(2017, 9, 19), initial_visible_month=datetime.date(2021, 11, 2)), Br(None), RadioItems(options=[{'label': 'NYU', 'value': 0}])], style={'border-style': 'solid', 'padding': '5em'})
#         global _one_shot = undefined
#     200         if not isinstance(chunks, (list, tuple)):
#     201             chunks = list(chunks)
#
# c:\Users\29468\anaconda3\lib\json\encoder.py in iterencode(
#     self=<_plotly_utils.utils.PlotlyJSONEncoder object>,
#     o=Div(children=[Header(children='These are some co...tyle={'border-style': 'solid', 'padding': '5em'}),
#     _one_shot=True
# )
#     255                 self.key_separator, self.item_separator, self.sort_keys,
#     256                 self.skipkeys, _one_shot)
# --> 257         return _iterencode(o, 0)
#         _iterencode = <_json.Encoder object at 0x000001C5847689A0>
#         o = Div(children=[Header(children='These are some common HTML tags', style={'font-size': '2em', 'color': 'blue', 'font-weight': 'bold'}), H1(children="H1 Tag - I am the first of the H's", style={'border-style': 'solid', 'border-width': 'thin'}), H3(children='H3 Tag', style={'border-style': 'solid', 'border-width': 'thin'}), H6(children="H6 Tag - I am the last of the H's", style={'border-style': 'solid', 'border-width': 'thin'}), H6(children="I'm a huge H6 thanks to my style", style={'border-style': 'solid', 'border-width': 'thin', 'font-size': '2em'}), P(children=['I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         ', 'I am a paragraph. &nbsp;         '], style={'border-style': 'solid', 'border-width': 'thin'}), Div(children=['I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          ', 'I am a div.          '], style={'border-style': 'solid', 'border-width': 'thin'}), Label(children=['I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. ', 'I am a label. '], style={'border-style': 'solid', 'border-width': 'thin', 'background': '#e7e7e7'}), Br(None), Br(None), Button('I am a button'), Br(None), Label('I am the label for the next image: (notice I cannot add space at the end)   '), Br(None), Img(src='https://steinhardt.nyu.edu/sites/default/files/styles/media_image_large/public/2019-08/nyu-logo-new.png?h=9396f34a&itok=hA0gNV3D', style={'height': '100px', 'width': '200px'}), Ul([Li('I am a list element'), Li('I am a list element')]), Textarea(placeholder='I am a text area with a placeholder'), Hr(None), Header(children='And these are some Dash Core Components', style={'font-size': '2em', 'color': 'blue', 'font-weight': 'bold'}), Label("DCC's are wrappers for regular html"), Dropdown(options=[{'label': 'NYU', 'value': 0}], placeholder='Select something...'), Input(type='text', placeholder='I am a text input'), Input(type='number', placeholder='I am also text input but I only take numbers'), Input(type='range', placeholder='Can I?'), Br(None), DatePickerRange(end_date=datetime.date(2021, 12, 25), min_date_allowed=datetime.date(1995, 8, 5), max_date_allowed=datetime.date(2017, 9, 19), initial_visible_month=datetime.date(2021, 11, 2)), Br(None), RadioItems(options=[{'label': 'NYU', 'value': 0}])], style={'border-style': 'solid', 'padding': '5em'})
#     258
#     259 def _make_iterencode(markers, _default, _encoder, _indent, _floatstr,
#
# c:\Users\29468\anaconda3\lib\site-packages\_plotly_utils\utils.py in default(
#     self=<_plotly_utils.utils.PlotlyJSONEncoder object>,
#     obj=datetime.date(2021, 12, 25)
# )
#     131         for encoding_method in encoding_methods:
#     132             try:
# --> 133                 return encoding_method(obj)
#         encoding_method = <function PlotlyJSONEncoder.encode_as_numpy at 0x000001C5844C5DC0>
#         obj = datetime.date(2021, 12, 25)
#     134             except NotEncodable:
#     135                 pass
#
# c:\Users\29468\anaconda3\lib\site-packages\_plotly_utils\utils.py in encode_as_numpy(obj=datetime.date(2021, 12, 25))
#     189             raise NotEncodable
#     190
# --> 191         if obj is numpy.ma.core.masked:
#         obj = datetime.date(2021, 12, 25)
#         numpy.ma.core.masked = undefined
#     192             return float("nan")
#     193         elif isinstance(obj, numpy.ndarray) and obj.dtype.kind == "M":
#
# AttributeError: partially initialized module 'numpy' has no attribute 'ma' (most likely due to a circular import)
#
# {'label': 'Fort Hunt', 'value': 0}
# {'label': 'Bessemer', 'value': 1}
# {'label': 'Paducah', 'value': 2}
# {'label': 'Birmingham', 'value': 3}
# {'label': 'Center Point', 'value': 4}
# {'label': 'Daphne', 'value': 5}
# {'label': 'Decatur', 'value': 6}
# {'label': 'Dothan', 'value': 7}
# {'label': 'East Florence', 'value': 8}
# {'label': 'Enterprise', 'value': 9}
# {'label': 'Fairhope', 'value': 10}
# {'label': 'Florence', 'value': 11}
# {'label': 'Gadsden', 'value': 12}
# {'label': 'Helena', 'value': 13}
# {'label': 'Homewood', 'value': 14}
# {'label': 'Hoover', 'value': 15}
# {'label': 'Hueytown', 'value': 16}
# {'label': 'Huntsville', 'value': 17}
# {'label': 'Madison', 'value': 18}
# {'label': 'Mobile', 'value': 19}
# {'label': 'Montgomery', 'value': 20}
# {'label': 'Mountain Brook', 'value': 21}
# {'label': 'Northport', 'value': 22}
# {'label': 'Opelika', 'value': 23}
# {'label': 'Oxford', 'value': 24}
# {'label': 'Pelham', 'value': 25}
# {'label': 'Phenix City', 'value': 26}
# {'label': 'Prattville', 'value': 27}
# {'label': 'Prichard', 'value': 28}
# {'label': 'Selma', 'value': 29}
# {'label': 'Talladega', 'value': 30}
# {'label': 'Tillmans Corner', 'value': 31}
# {'label': 'Troy', 'value': 32}
# {'label': 'Trussville', 'value': 33}
# {'label': 'Tuscaloosa', 'value': 34}
# {'label': 'Vestavia Hills', 'value': 35}
# {'label': 'Bella Vista', 'value': 36}
# {'label': 'Benton', 'value': 37}
# {'label': 'Bentonville', 'value': 38}
# {'label': 'Blytheville', 'value': 39}
# {'label': 'Bryant', 'value': 40}
# {'label': 'Cabot', 'value': 41}
# {'label': 'Conway', 'value': 42}
# {'label': 'El Dorado', 'value': 43}
# {'label': 'Fayetteville', 'value': 44}
# {'label': 'Forrest City', 'value': 45}
# {'label': 'Fort Smith', 'value': 46}
# {'label': 'Hot Springs', 'value': 47}
# {'label': 'Jacksonville', 'value': 48}
# {'label': 'Jonesboro', 'value': 49}
# {'label': 'Little Rock', 'value': 50}
# {'label': 'Maumelle', 'value': 51}
# {'label': 'North Little Rock', 'value': 52}
# {'label': 'Paragould', 'value': 53}
# {'label': 'Pine Bluff', 'value': 54}
# {'label': 'Rogers', 'value': 55}
# {'label': 'Russellville', 'value': 56}
# {'label': 'Searcy', 'value': 57}
# {'label': 'Siloam Springs', 'value': 58}
# {'label': 'Springdale', 'value': 59}
# {'label': 'Texarkana', 'value': 60}
# {'label': 'Van Buren', 'value': 61}
# {'label': 'West Memphis', 'value': 62}
# {'label': 'Washington, D.C.', 'value': 63}
# {'label': 'Bear', 'value': 64}
# {'label': 'Dover', 'value': 65}
# {'label': 'Middletown', 'value': 66}
# {'label': 'Newark', 'value': 67}
# {'label': 'Wilmington', 'value': 68}
# {'label': 'Allapattah', 'value': 69}
# {'label': 'Altamonte Springs', 'value': 70}
# {'label': 'Apopka', 'value': 71}
# {'label': 'Aventura', 'value': 72}
# {'label': 'Bartow', 'value': 73}
# {'label': 'Bayonet Point', 'value': 74}
# {'label': 'Bayshore Gardens', 'value': 75}
# {'label': 'Belle Glade', 'value': 76}
# {'label': 'Bellview', 'value': 77}
# {'label': 'Bloomingdale', 'value': 78}
# {'label': 'Boca Del Mar', 'value': 79}
# {'label': 'Boca Raton', 'value': 80}
# {'label': 'Bonita Springs', 'value': 81}
# {'label': 'Boynton Beach', 'value': 82}
# {'label': 'Bradenton', 'value': 83}
# {'label': 'Brandon', 'value': 84}
# {'label': 'Brent', 'value': 85}
# {'label': 'Brownsville', 'value': 86}
# {'label': 'Buenaventura Lakes', 'value': 87}
# {'label': 'Cantonment', 'value': 88}
# {'label': 'Cape Coral', 'value': 89}
# {'label': 'Carol City', 'value': 90}
# {'label': 'Carrollwood', 'value': 91}
# {'label': 'Carrollwood Village', 'value': 92}
# {'label': 'Casselberry', 'value': 93}
# {'label': 'Citrus Park', 'value': 94}
# {'label': 'Clearwater', 'value': 95}
# {'label': 'Clermont', 'value': 96}
# {'label': 'Cocoa', 'value': 97}
# {'label': 'Coconut Creek', 'value': 98}
# {'label': 'Coconut Grove', 'value': 99}
# {'label': 'Cooper City', 'value': 100}
# {'label': 'Coral Gables', 'value': 101}
# {'label': 'Coral Springs', 'value': 102}
# {'label': 'Coral Terrace', 'value': 103}
# {'label': 'Country Walk', 'value': 104}
# {'label': 'Country Club', 'value': 105}
# {'label': 'Crestview', 'value': 106}
# {'label': 'Cutler', 'value': 107}
# {'label': 'Cutler Ridge', 'value': 108}
# {'label': 'Dania Beach', 'value': 109}
# {'label': 'Davie', 'value': 110}
# {'label': 'Daytona Beach', 'value': 111}
# {'label': 'DeLand', 'value': 112}
# {'label': 'DeBary', 'value': 113}
# {'label': 'Deerfield Beach', 'value': 114}
# {'label': 'Delray Beach', 'value': 115}
# {'label': 'Deltona', 'value': 116}
# {'label': 'Doral', 'value': 117}
# {'label': 'Dunedin', 'value': 118}
# {'label': 'East Lake', 'value': 119}
# {'label': 'East Pensacola Heights', 'value': 120}
# {'label': 'Edgewater', 'value': 121}
# {'label': 'Egypt Lake-Leto', 'value': 122}
# {'label': 'Ensley', 'value': 123}
# {'label': 'Estero', 'value': 124}
# {'label': 'Eustis', 'value': 125}
# {'label': 'Ferry Pass', 'value': 126}
# {'label': 'Flagami', 'value': 127}
# {'label': 'Florida Ridge', 'value': 128}
# {'label': 'Fort Lauderdale', 'value': 129}
# {'label': 'Fort Myers', 'value': 130}
# {'label': 'Fort Pierce', 'value': 131}
# {'label': 'Fort Walton Beach', 'value': 132}
# {'label': 'Fountainebleau', 'value': 133}
# {'label': 'Fruit Cove', 'value': 134}
# {'label': 'Gainesville', 'value': 135}
# {'label': 'Glenvar Heights', 'value': 136}
# {'label': 'Golden Gate', 'value': 137}
# {'label': 'Golden Glades', 'value': 138}
# {'label': 'Greenacres City', 'value': 139}
# {'label': 'Haines City', 'value': 140}
# {'label': 'Hallandale Beach', 'value': 141}
# {'label': 'Hialeah', 'value': 142}
# {'label': 'Hialeah Gardens', 'value': 143}
# {'label': 'Holiday', 'value': 144}
# {'label': 'Hollywood', 'value': 145}
# {'label': 'Homestead', 'value': 146}
# {'label': 'Immokalee', 'value': 147}
# {'label': 'Iona', 'value': 148}
# {'label': 'Ives Estates', 'value': 149}
# {'label': 'Jacksonville', 'value': 150}
# {'label': 'Jacksonville Beach', 'value': 151}
# {'label': 'Jasmine Estates', 'value': 152}
# {'label': 'Jupiter', 'value': 153}
# {'label': 'Kendale Lakes', 'value': 154}
# {'label': 'Kendall', 'value': 155}
# {'label': 'Key West', 'value': 156}
# {'label': 'Keystone', 'value': 157}
# {'label': 'Kissimmee', 'value': 158}
# {'label': 'Lake Butler', 'value': 159}
# {'label': 'Lake Magdalene', 'value': 160}
# {'label': 'Lake Worth', 'value': 161}
# {'label': 'Lake Worth Corridor', 'value': 162}
# {'label': 'Lakeland', 'value': 163}
# {'label': 'Lakeside', 'value': 164}
# {'label': "Land O' Lakes", 'value': 165}
# {'label': 'Largo', 'value': 166}
# {'label': 'Lauderdale Lakes', 'value': 167}
# {'label': 'Lauderhill', 'value': 168}
# {'label': 'Lealman', 'value': 169}
# {'label': 'Leesburg', 'value': 170}
# {'label': 'Lehigh Acres', 'value': 171}
# {'label': 'Leisure City', 'value': 172}
# {'label': 'Lutz', 'value': 173}
# {'label': 'Lynn Haven', 'value': 174}
# {'label': 'Maitland', 'value': 175}
# {'label': 'Margate', 'value': 176}
# {'label': 'Meadow Woods', 'value': 177}
# {'label': 'Melbourne', 'value': 178}
# {'label': 'Merritt Island', 'value': 179}
# {'label': 'Miami', 'value': 180}
# {'label': 'Miami Beach', 'value': 181}
# {'label': 'Miami Gardens', 'value': 182}
# {'label': 'Miami Lakes', 'value': 183}
# {'label': 'Miramar', 'value': 184}
# {'label': 'Myrtle Grove', 'value': 185}
# {'label': 'Naples', 'value': 186}
# {'label': 'Navarre', 'value': 187}
# {'label': 'New Smyrna Beach', 'value': 188}
# {'label': 'Norland', 'value': 189}
# {'label': 'North Fort Myers', 'value': 190}
# {'label': 'North Lauderdale', 'value': 191}
# {'label': 'North Miami', 'value': 192}
# {'label': 'North Miami Beach', 'value': 193}
# {'label': 'North Port', 'value': 194}
# {'label': 'Oak Ridge', 'value': 195}
# {'label': 'Oakland Park', 'value': 196}
# {'label': 'Ocala', 'value': 197}
# {'label': 'Ocoee', 'value': 198}
# {'label': 'Ojus', 'value': 199}
# {'label': 'Opa-locka', 'value': 200}
# {'label': 'Orlando', 'value': 201}
# {'label': 'Ormond Beach', 'value': 202}
# {'label': 'Oviedo', 'value': 203}
# {'label': 'Pace', 'value': 204}
# {'label': 'Palm Bay', 'value': 205}
# {'label': 'Palm Beach Gardens', 'value': 206}
# {'label': 'Palm City', 'value': 207}
# {'label': 'Palm Coast', 'value': 208}
# {'label': 'Palm Harbor', 'value': 209}
# {'label': 'Palm Springs', 'value': 210}
# {'label': 'Palm Valley', 'value': 211}
# {'label': 'Palmetto Bay', 'value': 212}
# {'label': 'Panama City', 'value': 213}
# {'label': 'Parkland', 'value': 214}
# {'label': 'Pembroke Pines', 'value': 215}
# {'label': 'Pensacola', 'value': 216}
# {'label': 'Pine Hills', 'value': 217}
# {'label': 'Pinecrest', 'value': 218}
# {'label': 'Pinellas Park', 'value': 219}
# {'label': 'Pinewood', 'value': 220}
# {'label': 'Plant City', 'value': 221}
# {'label': 'Plantation', 'value': 222}
# {'label': 'Poinciana', 'value': 223}
# {'label': 'Pompano Beach', 'value': 224}
# {'label': 'Ponte Vedra Beach', 'value': 225}
# {'label': 'Port Charlotte', 'value': 226}
# {'label': 'Port Orange', 'value': 227}
# {'label': 'Port Saint Lucie', 'value': 228}
# {'label': 'Princeton', 'value': 229}
# {'label': 'Punta Gorda', 'value': 230}
# {'label': 'Punta Gorda Isles', 'value': 231}
# {'label': 'Richmond West', 'value': 232}
# {'label': 'Riverview', 'value': 233}
# {'label': 'Riviera Beach', 'value': 234}
# {'label': 'Rockledge', 'value': 235}
# {'label': 'Royal Palm Beach', 'value': 236}
# {'label': 'Ruskin', 'value': 237}
# {'label': 'Safety Harbor', 'value': 238}
# {'label': 'Saint Cloud', 'value': 239}
# {'label': 'Saint Petersburg', 'value': 240}
# {'label': 'San Carlos Park', 'value': 241}
# {'label': 'Sanford', 'value': 242}
# {'label': 'Sarasota', 'value': 243}
# {'label': 'Sebastian', 'value': 244}
# {'label': 'Seminole', 'value': 245}
# {'label': 'South Bradenton', 'value': 246}
# {'label': 'South Miami Heights', 'value': 247}
# {'label': 'Southchase', 'value': 248}
# {'label': 'Spring Hill', 'value': 249}
# {'label': 'Stuart', 'value': 250}
# {'label': 'Sun City Center', 'value': 251}
# {'label': 'Sunny Isles Beach', 'value': 252}
# {'label': 'Sunrise', 'value': 253}
# {'label': 'Sunset', 'value': 254}
# {'label': 'Tallahassee', 'value': 255}
# {'label': 'Tamarac', 'value': 256}
# {'label': 'Tamiami', 'value': 257}
# {'label': 'Tampa', 'value': 258}
# {'label': 'Tarpon Springs', 'value': 259}
# {'label': 'Temple Terrace', 'value': 260}
# {'label': 'The Crossings', 'value': 261}
# {'label': 'The Hammocks', 'value': 262}
# {'label': 'The Villages', 'value': 263}
# {'label': 'Three Lakes', 'value': 264}
# {'label': 'Titusville', 'value': 265}
# {'label': "Town 'n' Country", 'value': 266}
# {'label': 'University Park', 'value': 267}
# {'label': 'Valrico', 'value': 268}
# {'label': 'Venice', 'value': 269}
# {'label': 'Vero Beach', 'value': 270}
# {'label': 'Wekiwa Springs', 'value': 271}
# {'label': 'Wellington', 'value': 272}
# {'label': 'Wesley Chapel', 'value': 273}
# {'label': 'Westchase', 'value': 274}
# {'label': 'West Little River', 'value': 275}
# {'label': 'West Melbourne', 'value': 276}
# {'label': 'West Palm Beach', 'value': 277}
# {'label': 'West Pensacola', 'value': 278}
# {'label': 'West and East Lealman', 'value': 279}
# {'label': 'Westchester', 'value': 280}
# {'label': 'Weston', 'value': 281}
# {'label': 'Winter Garden', 'value': 282}
# {'label': 'Winter Haven', 'value': 283}
# {'label': 'Winter Park', 'value': 284}
# {'label': 'Winter Springs', 'value': 285}
# {'label': 'Wright', 'value': 286}
# {'label': 'Acworth', 'value': 287}
# {'label': 'Albany', 'value': 288}
# {'label': 'Alpharetta', 'value': 289}
# {'label': 'Americus', 'value': 290}
# {'label': 'Athens', 'value': 291}
# {'label': 'Atlanta', 'value': 292}
# {'label': 'Augusta', 'value': 293}
# {'label': 'Belvedere Park', 'value': 294}
# {'label': 'Brookhaven', 'value': 295}
# {'label': 'Brunswick', 'value': 296}
# {'label': 'Calhoun', 'value': 297}
# {'label': 'Canton', 'value': 298}
# {'label': 'Carrollton', 'value': 299}
# {'label': 'Cartersville', 'value': 300}
# {'label': 'Columbus', 'value': 301}
# {'label': 'Conyers', 'value': 302}
# {'label': 'Dalton', 'value': 303}
# {'label': 'Decatur', 'value': 304}
# {'label': 'Douglasville', 'value': 305}
# {'label': 'Dublin', 'value': 306}
# {'label': 'Duluth', 'value': 307}
# {'label': 'Dunwoody', 'value': 308}
# {'label': 'East Point', 'value': 309}
# {'label': 'Evans', 'value': 310}
# {'label': 'Fayetteville', 'value': 311}
# {'label': 'Forest Park', 'value': 312}
# {'label': 'Gainesville', 'value': 313}
# {'label': 'Griffin', 'value': 314}
# {'label': 'Hinesville', 'value': 315}
# {'label': 'Kennesaw', 'value': 316}
# {'label': 'Kingsland', 'value': 317}
# {'label': 'La Grange', 'value': 318}
# {'label': 'Lawrenceville', 'value': 319}
# {'label': 'Lithia Springs', 'value': 320}
# {'label': 'Mableton', 'value': 321}
# {'label': 'Macon', 'value': 322}
# {'label': 'Marietta', 'value': 323}
# {'label': 'Martinez', 'value': 324}
# {'label': 'McDonough', 'value': 325}
# {'label': 'Milledgeville', 'value': 326}
# {'label': 'Newnan', 'value': 327}
# {'label': 'North Decatur', 'value': 328}
# {'label': 'North Druid Hills', 'value': 329}
# {'label': 'Peachtree City', 'value': 330}
# {'label': 'Pooler', 'value': 331}
# {'label': 'Redan', 'value': 332}
# {'label': 'Riverdale', 'value': 333}
# {'label': 'Rome', 'value': 334}
# {'label': 'Roswell', 'value': 335}
# {'label': 'St. Marys', 'value': 336}
# {'label': 'Sandy Springs', 'value': 337}
# {'label': 'Savannah', 'value': 338}
# {'label': 'Smyrna', 'value': 339}
# {'label': 'Snellville', 'value': 340}
# {'label': 'Statesboro', 'value': 341}
# {'label': 'Stockbridge', 'value': 342}
# {'label': 'Sugar Hill', 'value': 343}
# {'label': 'Suwanee', 'value': 344}
# {'label': 'Thomasville', 'value': 345}
# {'label': 'Tifton', 'value': 346}
# {'label': 'Tucker', 'value': 347}
# {'label': 'Union City', 'value': 348}
# {'label': 'Valdosta', 'value': 349}
# {'label': 'Warner Robins', 'value': 350}
# {'label': 'Wilmington Island', 'value': 351}
# {'label': 'Woodstock', 'value': 352}
# {'label': 'Alton', 'value': 353}
# {'label': 'Belleville', 'value': 354}
# {'label': 'Cahokia', 'value': 355}
# {'label': 'Carbondale', 'value': 356}
# {'label': 'Charleston', 'value': 357}
# {'label': 'Collinsville', 'value': 358}
# {'label': 'Decatur', 'value': 359}
# {'label': 'East Saint Louis', 'value': 360}
# {'label': 'Edwardsville', 'value': 361}
# {'label': 'Fairview Heights', 'value': 362}
# {'label': 'Godfrey', 'value': 363}
# {'label': 'Granite City', 'value': 364}
# {'label': 'Jacksonville', 'value': 365}
# {'label': 'Marion', 'value': 366}
# {'label': 'Mattoon', 'value': 367}
# {'label': 'Mount Vernon', 'value': 368}
# {'label': "O'Fallon", 'value': 369}
# {'label': 'Quincy', 'value': 370}
# {'label': 'Springfield', 'value': 371}
# {'label': 'Upper Alton', 'value': 372}
# {'label': 'Bloomington', 'value': 373}
# {'label': 'Broad Ripple', 'value': 374}
# {'label': 'Brownsburg', 'value': 375}
# {'label': 'Carmel', 'value': 376}
# {'label': 'Clarksville', 'value': 377}
# {'label': 'Columbus', 'value': 378}
# {'label': 'Evansville', 'value': 379}
# {'label': 'Fishers', 'value': 380}
# {'label': 'Greenfield', 'value': 381}
# {'label': 'Greenwood', 'value': 382}
# {'label': 'Indianapolis', 'value': 383}
# ...
# {'label': 'Truckee', 'value': 2288}
# {'label': 'Tulare', 'value': 2289}
# {'label': 'Turlock', 'value': 2290}
# {'label': 'Tustin', 'value': 2291}
# {'label': 'North Tustin', 'value': 2292}
# {'label': 'Twentynine Palms', 'value': 2293}
# {'label': 'Ukiah', 'value': 2294}
# {'label': 'Union City', 'value': 2295}
# {'label': 'Universal City', 'value': 2296}
# {'label': 'Upland', 'value': 2297}
# {'label': 'Walnut Park', 'value': 2298}
# {'label': 'Watsonville', 'value': 2299}
# {'label': 'West Carson', 'value': 2300}
# {'label': 'West Covina', 'value': 2301}
# {'label': 'West Hollywood', 'value': 2302}
# {'label': 'West Puente Valley', 'value': 2303}
# {'label': 'West Sacramento', 'value': 2304}
# {'label': 'Westminster', 'value': 2305}
# {'label': 'Westmont', 'value': 2306}
# {'label': 'Whittier', 'value': 2307}
# {'label': 'Wildomar', 'value': 2308}
# {'label': 'Willowbrook', 'value': 2309}
# {'label': 'Windsor', 'value': 2310}
# {'label': 'Winter Gardens', 'value': 2311}
# {'label': 'Woodland', 'value': 2312}
# {'label': 'Woodland Hills', 'value': 2313}
# {'label': 'Yorba Linda', 'value': 2314}
# {'label': 'Yuba City', 'value': 2315}
# {'label': 'Yucaipa', 'value': 2316}
# {'label': 'Yucca Valley', 'value': 2317}
# {'label': 'Arvada', 'value': 2318}
# {'label': 'Aurora', 'value': 2319}
# {'label': 'Brighton', 'value': 2320}
# {'label': 'Broomfield', 'value': 2321}
# {'label': 'Cañon City', 'value': 2322}
# {'label': 'Castle Rock', 'value': 2323}
# {'label': 'Castlewood', 'value': 2324}
# {'label': 'Centennial', 'value': 2325}
# {'label': 'Cimarron Hills', 'value': 2326}
# {'label': 'Clifton', 'value': 2327}
# {'label': 'Colorado Springs', 'value': 2328}
# {'label': 'Columbine', 'value': 2329}
# {'label': 'Commerce City', 'value': 2330}
# {'label': 'Denver', 'value': 2331}
# {'label': 'Durango', 'value': 2332}
# {'label': 'Englewood', 'value': 2333}
# {'label': 'Fountain', 'value': 2334}
# {'label': 'Golden', 'value': 2335}
# {'label': 'Grand Junction', 'value': 2336}
# {'label': 'Highlands Ranch', 'value': 2337}
# {'label': 'Ken Caryl', 'value': 2338}
# {'label': 'Lafayette', 'value': 2339}
# {'label': 'Lakewood', 'value': 2340}
# {'label': 'Littleton', 'value': 2341}
# {'label': 'Louisville', 'value': 2342}
# {'label': 'Montrose', 'value': 2343}
# {'label': 'Northglenn', 'value': 2344}
# {'label': 'Parker', 'value': 2345}
# {'label': 'Pueblo', 'value': 2346}
# {'label': 'Pueblo West', 'value': 2347}
# {'label': 'Sherrelwood', 'value': 2348}
# {'label': 'Southglenn', 'value': 2349}
# {'label': 'Thornton', 'value': 2350}
# {'label': 'Westminster', 'value': 2351}
# {'label': 'Wheat Ridge', 'value': 2352}
# {'label': 'Dodge City', 'value': 2353}
# {'label': 'Garden City', 'value': 2354}
# {'label': 'Liberal', 'value': 2355}
# {'label': 'Alamogordo', 'value': 2356}
# {'label': 'Albuquerque', 'value': 2357}
# {'label': 'Carlsbad', 'value': 2358}
# {'label': 'Clovis', 'value': 2359}
# {'label': 'Farmington', 'value': 2360}
# {'label': 'Gallup', 'value': 2361}
# {'label': 'Hobbs', 'value': 2362}
# {'label': 'Las Cruces', 'value': 2363}
# {'label': 'Rio Rancho', 'value': 2364}
# {'label': 'Roswell', 'value': 2365}
# {'label': 'Santa Fe', 'value': 2366}
# {'label': 'South Valley', 'value': 2367}
# {'label': 'Boulder City', 'value': 2368}
# {'label': 'Carson City', 'value': 2369}
# {'label': 'Enterprise', 'value': 2370}
# {'label': 'Fernley', 'value': 2371}
# {'label': 'Henderson', 'value': 2372}
# {'label': 'Las Vegas', 'value': 2373}
# {'label': 'Mesquite', 'value': 2374}
# {'label': 'North Las Vegas', 'value': 2375}
# {'label': 'Pahrump', 'value': 2376}
# {'label': 'Paradise', 'value': 2377}
# {'label': 'Reno', 'value': 2378}
# {'label': 'Spanish Springs', 'value': 2379}
# {'label': 'Sparks', 'value': 2380}
# {'label': 'Spring Valley', 'value': 2381}
# {'label': 'Sun Valley', 'value': 2382}
# {'label': 'Sunrise Manor', 'value': 2383}
# {'label': 'Whitney', 'value': 2384}
# {'label': 'Winchester', 'value': 2385}
# {'label': 'Amarillo', 'value': 2386}
# {'label': 'Big Spring', 'value': 2387}
# {'label': 'Del Rio', 'value': 2388}
# {'label': 'Eagle Pass', 'value': 2389}
# {'label': 'El Paso', 'value': 2390}
# {'label': 'Hereford', 'value': 2391}
# {'label': 'Horizon City', 'value': 2392}
# {'label': 'Lubbock', 'value': 2393}
# {'label': 'Midland', 'value': 2394}
# {'label': 'Odessa', 'value': 2395}
# {'label': 'Pampa', 'value': 2396}
# {'label': 'Plainview', 'value': 2397}
# {'label': 'San Angelo', 'value': 2398}
# {'label': 'Socorro', 'value': 2399}
# {'label': 'Socorro Mission Number 1 Colonia', 'value': 2400}
# {'label': 'West Odessa', 'value': 2401}
# {'label': 'Cedar City', 'value': 2402}
# {'label': 'Saint George', 'value': 2403}
# {'label': 'Washington', 'value': 2404}
# {'label': 'Wasco', 'value': 2405}
# {'label': 'Anthem', 'value': 2406}
# {'label': 'Apache Junction', 'value': 2407}
# {'label': 'Avondale', 'value': 2408}
# {'label': 'Juneau', 'value': 2409}
# {'label': 'Arcata', 'value': 2410}
# {'label': 'Bayside', 'value': 2411}
# {'label': 'Eureka', 'value': 2412}
# {'label': 'McKinleyville', 'value': 2413}
# {'label': 'Redding', 'value': 2414}
# {'label': 'Susanville', 'value': 2415}
# {'label': 'Boulder', 'value': 2416}
# {'label': 'Erie', 'value': 2417}
# {'label': 'Evans', 'value': 2418}
# {'label': 'Fort Collins', 'value': 2419}
# {'label': 'Greeley', 'value': 2420}
# {'label': 'Longmont', 'value': 2421}
# {'label': 'Loveland', 'value': 2422}
# {'label': 'Windsor', 'value': 2423}
# {'label': 'Boise', 'value': 2424}
# {'label': 'Caldwell', 'value': 2425}
# {'label': "Coeur d'Alene", 'value': 2426}
# {'label': 'Eagle', 'value': 2427}
# {'label': 'Idaho Falls', 'value': 2428}
# {'label': 'Kuna', 'value': 2429}
# {'label': 'Lewiston', 'value': 2430}
# {'label': 'Lewiston Orchards', 'value': 2431}
# {'label': 'Meridian', 'value': 2432}
# {'label': 'Moscow', 'value': 2433}
# {'label': 'Nampa', 'value': 2434}
# {'label': 'Pocatello', 'value': 2435}
# {'label': 'Post Falls', 'value': 2436}
# {'label': 'Rexburg', 'value': 2437}
# {'label': 'Twin Falls', 'value': 2438}
# {'label': 'Billings', 'value': 2439}
# {'label': 'Bozeman', 'value': 2440}
# {'label': 'Butte', 'value': 2441}
# {'label': 'Great Falls', 'value': 2442}
# {'label': 'Helena', 'value': 2443}
# {'label': 'Kalispell', 'value': 2444}
# {'label': 'Missoula', 'value': 2445}
# {'label': 'Bismarck', 'value': 2446}
# {'label': 'Dickinson', 'value': 2447}
# {'label': 'Mandan', 'value': 2448}
# {'label': 'Minot', 'value': 2449}
# {'label': 'North Platte', 'value': 2450}
# {'label': 'Scottsbluff', 'value': 2451}
# {'label': 'Elko', 'value': 2452}
# {'label': 'Albany', 'value': 2453}
# {'label': 'Aloha', 'value': 2454}
# {'label': 'Altamont', 'value': 2455}
# {'label': 'Ashland', 'value': 2456}
# {'label': 'Beaverton', 'value': 2457}
# {'label': 'Bend', 'value': 2458}
# {'label': 'Bethany', 'value': 2459}
# {'label': 'Canby', 'value': 2460}
# {'label': 'Central Point', 'value': 2461}
# {'label': 'Coos Bay', 'value': 2462}
# {'label': 'Corvallis', 'value': 2463}
# {'label': 'Eugene', 'value': 2464}
# {'label': 'Forest Grove', 'value': 2465}
# {'label': 'Four Corners', 'value': 2466}
# {'label': 'Grants Pass', 'value': 2467}
# {'label': 'Gresham', 'value': 2468}
# {'label': 'Hayesville', 'value': 2469}
# {'label': 'Hermiston', 'value': 2470}
# {'label': 'Hillsboro', 'value': 2471}
# {'label': 'Keizer', 'value': 2472}
# {'label': 'Klamath Falls', 'value': 2473}
# {'label': 'Lake Oswego', 'value': 2474}
# {'label': 'Lebanon', 'value': 2475}
# {'label': 'Lents', 'value': 2476}
# {'label': 'McMinnville', 'value': 2477}
# {'label': 'Medford', 'value': 2478}
# {'label': 'Milwaukie', 'value': 2479}
# {'label': 'Newberg', 'value': 2480}
# {'label': 'Oak Grove', 'value': 2481}
# {'label': 'Oregon City', 'value': 2482}
# {'label': 'Pendleton', 'value': 2483}
# {'label': 'Portland', 'value': 2484}
# {'label': 'Redmond', 'value': 2485}
# {'label': 'Roseburg', 'value': 2486}
# {'label': 'Salem', 'value': 2487}
# {'label': 'Sherwood', 'value': 2488}
# {'label': 'Springfield', 'value': 2489}
# {'label': 'Tigard', 'value': 2490}
# {'label': 'Troutdale', 'value': 2491}
# {'label': 'Tualatin', 'value': 2492}
# {'label': 'West Linn', 'value': 2493}
# {'label': 'Wilsonville', 'value': 2494}
# {'label': 'Woodburn', 'value': 2495}
# {'label': 'Rapid City', 'value': 2496}
# {'label': 'Bountiful', 'value': 2497}
# {'label': 'Brigham City', 'value': 2498}
# {'label': 'Centerville', 'value': 2499}
# {'label': 'Clearfield', 'value': 2500}
# {'label': 'Clinton', 'value': 2501}
# {'label': 'Cottonwood Heights', 'value': 2502}
# {'label': 'Draper', 'value': 2503}
# {'label': 'Eagle Mountain', 'value': 2504}
# {'label': 'East Millcreek', 'value': 2505}
# {'label': 'Farmington', 'value': 2506}
# {'label': 'Herriman', 'value': 2507}
# {'label': 'Highland', 'value': 2508}
# {'label': 'Holladay', 'value': 2509}
# {'label': 'Kaysville', 'value': 2510}
# {'label': 'Kearns', 'value': 2511}
# {'label': 'Layton', 'value': 2512}
# {'label': 'Lehi', 'value': 2513}
# {'label': 'Logan', 'value': 2514}
# {'label': 'Magna', 'value': 2515}
# {'label': 'Midvale', 'value': 2516}
# {'label': 'Millcreek', 'value': 2517}
# {'label': 'Murray', 'value': 2518}
# {'label': 'North Ogden', 'value': 2519}
# {'label': 'North Salt Lake', 'value': 2520}
# {'label': 'Ogden', 'value': 2521}
# {'label': 'Orem', 'value': 2522}
# {'label': 'Payson', 'value': 2523}
# {'label': 'Pleasant Grove', 'value': 2524}
# {'label': 'Provo', 'value': 2525}
# {'label': 'Riverton', 'value': 2526}
# {'label': 'Roy', 'value': 2527}
# {'label': 'Salt Lake City', 'value': 2528}
# {'label': 'Sandy City', 'value': 2529}
# {'label': 'Sandy Hills', 'value': 2530}
# {'label': 'Saratoga Springs', 'value': 2531}
# {'label': 'South Jordan Heights', 'value': 2532}
# {'label': 'South Jordan', 'value': 2533}
# {'label': 'South Ogden', 'value': 2534}
# {'label': 'South Salt Lake', 'value': 2535}
# {'label': 'Spanish Fork', 'value': 2536}
# {'label': 'Springville', 'value': 2537}
# {'label': 'Syracuse', 'value': 2538}
# {'label': 'Taylorsville', 'value': 2539}
# {'label': 'Tooele', 'value': 2540}
# {'label': 'West Jordan', 'value': 2541}
# {'label': 'West Valley City', 'value': 2542}
# {'label': 'Aberdeen', 'value': 2543}
# {'label': 'Anacortes', 'value': 2544}
# {'label': 'Arlington', 'value': 2545}
# {'label': 'Auburn', 'value': 2546}
# {'label': 'Battle Ground', 'value': 2547}
# {'label': 'Bellevue', 'value': 2548}
# {'label': 'Bellingham', 'value': 2549}
# {'label': 'Bonney Lake', 'value': 2550}
# {'label': 'Bothell', 'value': 2551}
# {'label': 'Bremerton', 'value': 2552}
# {'label': 'Burien', 'value': 2553}
# {'label': 'Camas', 'value': 2554}
# {'label': 'Centralia', 'value': 2555}
# {'label': 'Cottage Lake', 'value': 2556}
# {'label': 'Covington', 'value': 2557}
# {'label': 'Des Moines', 'value': 2558}
# {'label': 'Edmonds', 'value': 2559}
# {'label': 'Ellensburg', 'value': 2560}
# {'label': 'Everett', 'value': 2561}
# {'label': 'Fairwood', 'value': 2562}
# {'label': 'Federal Way', 'value': 2563}
# {'label': 'Five Corners', 'value': 2564}
# {'label': 'Frederickson', 'value': 2565}
# {'label': 'Graham', 'value': 2566}
# {'label': 'Hazel Dell', 'value': 2567}
# {'label': 'Issaquah', 'value': 2568}
# {'label': 'Kenmore', 'value': 2569}
# {'label': 'Kennewick', 'value': 2570}
# {'label': 'Kent', 'value': 2571}
# {'label': 'Kirkland', 'value': 2572}
# {'label': 'Lacey', 'value': 2573}
# {'label': 'Lake Stevens', 'value': 2574}
# {'label': 'Lakewood', 'value': 2575}
# {'label': 'Longview', 'value': 2576}
# {'label': 'Lynnwood', 'value': 2577}
# {'label': 'Maple Valley', 'value': 2578}
# {'label': 'Martha Lake', 'value': 2579}
# {'label': 'Marysville', 'value': 2580}
# {'label': 'Mercer Island', 'value': 2581}
# {'label': 'Mill Creek', 'value': 2582}
# {'label': 'Monroe', 'value': 2583}
# {'label': 'Moses Lake', 'value': 2584}
# {'label': 'Mount Vernon', 'value': 2585}
# {'label': 'Mountlake Terrace', 'value': 2586}
# {'label': 'Mukilteo', 'value': 2587}
# {'label': 'North Creek', 'value': 2588}
# {'label': 'Oak Harbor', 'value': 2589}
# {'label': 'Olympia', 'value': 2590}
# {'label': 'Opportunity', 'value': 2591}
# {'label': 'Orchards', 'value': 2592}
# {'label': 'Parkland', 'value': 2593}
# {'label': 'Pasco', 'value': 2594}
# {'label': 'Port Angeles', 'value': 2595}
# {'label': 'Pullman', 'value': 2596}
# {'label': 'Puyallup', 'value': 2597}
# {'label': 'Redmond', 'value': 2598}
# {'label': 'Renton', 'value': 2599}
# {'label': 'Richland', 'value': 2600}
# {'label': 'Salmon Creek', 'value': 2601}
# {'label': 'Sammamish', 'value': 2602}
# {'label': 'SeaTac', 'value': 2603}
# {'label': 'Seattle', 'value': 2604}
# {'label': 'Shoreline', 'value': 2605}
# {'label': 'Silverdale', 'value': 2606}
# {'label': 'South Hill', 'value': 2607}
# {'label': 'Spanaway', 'value': 2608}
# {'label': 'Spokane', 'value': 2609}
# {'label': 'Spokane Valley', 'value': 2610}
# {'label': 'Sunnyside', 'value': 2611}
# {'label': 'Tacoma', 'value': 2612}
# {'label': 'Tukwila', 'value': 2613}
# {'label': 'Tumwater', 'value': 2614}
# {'label': 'University Place', 'value': 2615}
# {'label': 'Vancouver', 'value': 2616}
# {'label': 'Walla Walla', 'value': 2617}
# {'label': 'Wenatchee', 'value': 2618}
# {'label': 'West Lake Sammamish', 'value': 2619}
# {'label': 'West Lake Stevens', 'value': 2620}
# {'label': 'Bainbridge Island', 'value': 2621}
# {'label': 'Yakima', 'value': 2622}
# {'label': 'Casper', 'value': 2623}
# {'label': 'Cheyenne', 'value': 2624}
# {'label': 'Gillette', 'value': 2625}
# {'label': 'Laramie', 'value': 2626}
# {'label': 'Rock Springs', 'value': 2627}
# {'label': 'Sheridan', 'value': 2628}
# {'label': 'American Fork', 'value': 2629}
# {'label': 'Kahului', 'value': 2630}
# {'label': 'Kailua', 'value': 2631}
# {'label': 'Kāne‘ohe', 'value': 2632}
# {'label': 'Kīhei', 'value': 2633}
# {'label': 'Makakilo City', 'value': 2634}
# {'label': 'Mililani Town', 'value': 2635}
# {'label': 'Pearl City', 'value': 2636}
# {'label': 'Wahiawā', 'value': 2637}
# {'label': 'Wailuku', 'value': 2638}
# {'label': 'Waipahu', 'value': 2639}
# {'label': '‘Ewa Gentry', 'value': 2640}
# {'label': 'Hilo', 'value': 2641}
# {'label': 'Honolulu', 'value': 2642}
# {'label': 'Eagle River', 'value': 2643}
# {'label': 'Fairbanks', 'value': 2644}
# {'label': 'Anchorage', 'value': 2645}
# {'label': 'Badger', 'value': 2646}
# {'label': 'Milton', 'value': 2647}
# {'label': 'Johns Creek', 'value': 2648}
# {'label': 'Cutler Bay', 'value': 2649}
# {'label': 'Alafaya', 'value': 2650}
# {'label': 'Fort Bragg', 'value': 2651}
# {'label': 'City of Milford (balance)', 'value': 2652}
# {'label': 'Butte-Silver Bow (Balance)', 'value': 2653}
# {'label': 'City of Sammamish', 'value': 2654}
# {'label': 'Silver Firs', 'value': 2655}
# {'label': 'Vineyard', 'value': 2656}
# {'label': 'Wallingford Center', 'value': 2657}
# {'label': 'Bel Air North', 'value': 2658}
# {'label': 'Bel Air South', 'value': 2659}
# {'label': 'Setauket-East Setauket', 'value': 2660}
# {'label': 'Tonawanda', 'value': 2661}
# {'label': 'Fort Leonard Wood', 'value': 2662}
# {'label': 'West Bloomfield Township', 'value': 2663}
# {'label': 'East Lake-Orient Park', 'value': 2664}
# {'label': 'Four Corners', 'value': 2665}
# {'label': 'Greater Northdale', 'value': 2666}
# {'label': 'Candler-McAfee', 'value': 2667}
# {'label': 'University', 'value': 2668}
# {'label': 'Vero Beach South', 'value': 2669}
# {'label': 'Kendall West', 'value': 2670}
# {'label': 'Palm River-Clair Mel', 'value': 2671}
# {'label': 'Arden-Arcade', 'value': 2672}
# {'label': 'Bryn Mawr-Skyway', 'value': 2673}
# {'label': 'Casa de Oro-Mount Helix', 'value': 2674}
# {'label': 'Florence-Graham', 'value': 2675}
# {'label': 'Fort Hood', 'value': 2676}
# {'label': 'Inglewood-Finn Hill', 'value': 2677}
# {'label': 'La Crescenta-Montrose', 'value': 2678}
# {'label': 'East Hill-Meridian', 'value': 2679}
# {'label': 'Security-Widefield', 'value': 2680}
# {'label': 'Union Hill-Novelty Hill', 'value': 2681}
# {'label': 'West Whittier-Los Nietos', 'value': 2682}
# {'label': 'Summerlin South', 'value': 2683}
# {'label': 'Makakilo', 'value': 2684}
# {'label': 'Schofield Barracks', 'value': 2685}
# {'label': 'San Tan Valley', 'value': 2686}
# {'label': 'Enchanted Hills', 'value': 2687}
# {'label': 'West Hills', 'value': 2688}
# {'label': 'Oak Hill', 'value': 2689}
# {'label': 'Bridgewater', 'value': 2690}
# {'label': 'Warren Township', 'value': 2691}
# {'label': 'Fairfield Heights', 'value': 2692}
# {'label': 'Randolph', 'value': 2693}
# {'label': 'Hot Springs National Park', 'value': 2694}
# {'label': 'Dixiana', 'value': 2695}
# {'label': 'Cranberry Township', 'value': 2696}
# {'label': 'Silver Lake', 'value': 2697}
# {'label': 'Echo Park', 'value': 2698}

# %%
# Extra variables
from datetime import date

# First thing we need to do is create the contents and initialize the app
app = JupyterDash(__name__)     # in a python py file this should be app = dash.Dash()

app.layout = html.Div(
    [
        html.H4('Sandbox for DCC componenets'),
        dcc.Dropdown(
            options=city_options,
            placeholder = 'Select something...'
        ),
        
        # There are hidden options here
        html.Br(),
        dcc.Dropdown(
            options=[{'label': city['label'], 'value': city['label']} for city in city_options],
            #placeholder = 'Not so fast, select above first',
            #disabled = True,
            #searchable = False,
            multi=True
        ),
        
        html.Br(),html.Br(),
        dcc.Input(
            type='text',
            placeholder='This one does not have much to add - the textarea is more complete',
            style = {'width': '100vw'}
        ),
        
        html.Br(),html.Br(),
        html.Label('I am a number only input with some boundries'),
        html.Br(),
        dcc.Input(
            type='number',
            placeholder='number',
            min = -10, 
            max = 100, 
            step = 0.03
        ),
        
        html.Br(),html.Br(),
        html.Label("Here's an input range with the same settings as the number input, but no labels available "),
        html.Br(),
        dcc.Input(
            type='range',
            min = 10, 
            max = 100, 
            step = 3
        ),
        
        html.Br(),
        html.Label("So, use a dcc.RangeSlider instead. The marks and number of selections are fully customizable"),
        html.Br(),
        dcc.RangeSlider(
            min=10,
            
            max=100,
            value=[30],
            # value=[30,50],
            marks={
                #10: {'label': '10'},
                #60: {'label': 'Center Value'},
                #100: {'label': '100', 'style': {'color': '#f50'}}
            }
        ),
        
        html.Br(),
        html.Label('Finally, the radio uses the same options as the cities but sliced to 5'),
        html.Br(),
        dcc.Checklist(
            options = city_options[:5],
            value = [1, 3],
            # Some components allow you to differentiate between styles -> not so friendly though
            # labelStyle = {'display': 'flex', 'flex-direction': 'column'}
            labelStyle = {'display': 'flex', 'flex-direction': 'row'}   
            # make it a dcc.Checklist if needed as checkboxes
        ),
        
    ], style = {'border-style': 'solid', 'padding': '5em'}
)

# This is always the last line where the app is actually instanciated
app.run_server(
    mode = 'inline'
)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %% [markdown]
# ### Let's now create full components dynamically

# %%
# Since the children are list elements, we can use list comprehension to create elements dynamically
n_texts = 7

# %%
# Extra variables
from datetime import date

# First thing we need to do is create the contents and initialize the app
app = JupyterDash(__name__)     # in a python py file this should be app = dash.Dash()

def get_ti(x):
    content = dcc.Input(
        type='text',
        placeholder='I am textbox #{}'.format(x+1)
    )
    return(content)

app.layout = html.Div(
    [
        html.H4('Sandbox for DCC dynamic componenets'),
        
        dcc.Markdown('''
             This takes the number from the prior cell and creates the corresponding number of text components\n
             The only thing needed is a way to use the list comprehension, so let's create another div inside and use the children.\n
             I am a markdown component btw'''
        ),
        
        html.Div(
            [get_ti(x) for x in range(n_texts)], 
            style = {
                'display': 'flex', 'flex-direction': 'column', 'border-style': 'solid', 'padding': '1em', 
                        'border-color':'blue'}
        )
        
    ],
    style ={'border-style': 'solid', 'padding': '1em'}
)

# This is always the last line where the app is actually instanciated
app.run_server(
    mode = 'inline'
)
# Out:
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>

# %%
import dash
import pandas as pd
import yfinance as yf
import plotly.express as px
from dash import Dash, html, dcc

#%% Data Download Section
ticker = 'AAPL'
myTicker = yf.Ticker(ticker)
hist = myTicker.history(period="max")

hist = hist.reset_index()
hist['Date'] = pd.to_datetime(hist['Date'], errors = 'coerce')

hist['Date'].max()
#%% Graph generation
fig = px.scatter(hist, y="Open", x='Date')

# The update_layout method allows us to give some formatting to the graph
fig.update_layout(
    title_text = "Time Series Plot of {}".format(ticker),
    title_x = 0.5,
    yaxis = {
        'title': 'Price'}
)

# Add range slider
fig.update_layout(
    xaxis=dict(
        rangeselector=dict(
            buttons=list([
                dict(count=1,
                     label="1m",
                     step="month",
                     # stepmode="backward"
                     ),
                dict(count=6,
                     label="6m",
                     step="month",
                     # stepmode="backward"
                     ),
                dict(count=1,
                     label="YTD",
                     step="year",
                     # stepmode="todate"
                     ),
                dict(count=1,
                     label="1y",
                     step="year",
                     # stepmode="backward"
                     ),
                dict(step="all")
            ])
        ),
        rangeslider=dict(
            visible=False
        ),
        # type="date",
        # title='This is a date'
    )
)
def get_ti(x):
    content = dcc.Input(
        type='text',
        placeholder='Type something here #{}'.format(x+1)
    )
    return(content)

#%% Dash app
# app = Dash()
app = JupyterDash(__name__)

app.layout = html.Div(
    [
        html.Center(html.H4('My Very First Dash App - Yey!!!')),
        
        html.Div('''
             This app displays a graph of the entire price history of {}.'''.format(ticker),
             style = {
                 'width': '60%',
                 'text-align': 'center',
                 'margin-left': 'auto',
                 'margin-right': 'auto',
             }
        ),
        
        dcc.Graph(figure = fig),
        html.Div([get_ti(1)],
                style = {
                'display': 'flex', 'flex-direction': 'column', 'border-style': 'solid', 'padding': '1em', 
                        'border-color':'blue'}
        ),

        html.Br(),
        dcc.Dropdown(
            options=[{"label": "AAPL", "value":1}, {"label": "AMZN", "value":2}]
        )
        
        
    ],  #I could also put the list comprehension here
    style ={
        'margin': '2em',
        'border-radius': '1em',
        'border-style': 'solid', 
        'padding': '2em',
        'background': '#ededed'
    }
)
       
print('About to start...')
                 
app.run_server(
    mode = 'inline'
)
# Out:
# About to start...
#         <iframe
#             width="100%"
#             height="650"
#             src="http://127.0.0.1:8050/"
#             frameborder="0"
#             allowfullscreen
#
#         ></iframe>
